# %%
! pip install transformers peft accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 16.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 20.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 19.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 31.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
from transformers import pipeline
from peft import PeftModel, PeftConfig
from transformers import AutoModelForCausalLM, AutoTokenizer


hf_peft_repo = "/content/drive/MyDrive/Developments/open-calm-7b-tsukuyomi"
peft_config = PeftConfig.from_pretrained(hf_peft_repo)

model = AutoModelForCausalLM.from_pretrained(
    peft_config.base_model_name_or_path,
    return_dict=True,
    torch_dtype=torch.float16,
    device_map='auto'
    )

model = PeftModel.from_pretrained(model, hf_peft_repo)

tokenizer = AutoTokenizer.from_pretrained(peft_config.base_model_name_or_path)



inputs = tokenizer("AIによって私達の暮らしは、", return_tensors="pt").to(model.device)
with torch.no_grad():
    tokens = model.generate(
        **inputs,
        max_new_tokens=64,
        do_sample=True,
        temperature=0.7,
        top_p=0.9,
        repetition_penalty=1.05,
        pad_token_id=tokenizer.pad_token_id,
    )

output = tokenizer.decode(tokens[0], skip_special_tokens=True)
print(output)
# Out:
# ...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-999377b961d5> in <cell line: 10>()
#       8 peft_config = PeftConfig.from_pretrained(hf_peft_repo)
#       9
# ---> 10 model = AutoModelForCausalLM.from_pretrained(
#      11     peft_config.base_model_name_or_path,
#      12     return_dict=True,
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     491         elif type(config) in cls._model_mapping.keys():
#     492             model_class = _get_model_class(config, cls._model_mapping)
# --> 493             return model_class.from_pretrained(
#     494                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     495             )
#
# ...

# %%
inputs = tokenizer("""次は私とあなたの会話履歴です。あなた：を補完してください。
私：こんにちは, あなた：お元気ですか?,
私：元気ですよ, あなた：私も元気で過ごしていますよ!
私：今日は何してたの？, あなた：私は今、仕事中ですが、あなたはいかがですか?
私：勉強をしています, あなた：そうなんですか。頑張ってくださいね。
私：好きなものはなんですか？, あなた：読書と料理が好きです。
私：つくよみちゃんは読書がすきなんですね, あなた：はい、大好きです。
私：どんなジャンルの本が好きですか？, あなた：小説を読むのが好きです。
私：最近読んだ小説はありますか？, あなた：最近は『星の王子さま』を読んでいました。
私：どんな内容でしたか？, あなた：キツネと王子さまの友情の話でした。
私：他に読んだ本はありますか？, あなた：""", return_tensors="pt").to(model.device)
with torch.no_grad():
    tokens = model.generate(
        **inputs,
        max_new_tokens=30,
        do_sample=True,
        temperature=0.7,
        top_p=0.9,
        repetition_penalty=1.05,
        pad_token_id=tokenizer.pad_token_id,
    )

output = tokenizer.decode(tokens[0], skip_special_tokens=True)
print(output)
# Out:
# 次は私とあなたの会話履歴です。あなた:を補完してください。
# 私:こんにちは, あなた:お元気ですか?,
# 私:元気ですよ, あなた:私も元気で過ごしていますよ!
# 私:今日は何してたの?, あなた:私は今、仕事中ですが、あなたはいかがですか?
# 私:勉強をしています, あなた:そうなんですか。頑張ってくださいね。
# 私:好きなものはなんですか?, あなた:読書と料理が好きです。
# 私:つくよみちゃんは読書がすきなんですね, あなた:はい、大好きです。
# 私:どんなジャンルの本が好きですか?, あなた:小説を読むのが好きです。
# 私:最近読んだ小説はありますか?, あなた:最近は『星の王子さま』を読んでいました。
# 私:どんな内容でしたか?, あなた:キツネと王子さまの友情の話でした。
# 私:他に読んだ本はありますか?, あなた:村上春樹さんの『ノルウェイの森』は読みました。文章の美しさと描写の美しさで感動しました。あとは、『水族船の航跡―芥川龍
